# %%
import pandas as pd
from getpass import getuser
import os

# %%
# =============================
# CONFIG
# =============================
USER = getuser()
INPUT_DIR = f"C:/Users/{USER}/Documents/GitHub/tennis-homophily/data/atp/"
INPUT_FILE = os.path.join(INPUT_DIR, "men_matches_with_ranks_cleaned.xlsx") 
OUTPUT_FILE = os.path.join(INPUT_DIR, "pairs_df.xlsx")

# =============================
# Load Dataset
# =============================
print("Loading Grand Slam matches…")
if not os.path.exists(INPUT_FILE):
    raise FileNotFoundError(f"Grand Slam file not found: {INPUT_FILE}")

df = pd.read_excel(INPUT_FILE)
print(df.shape)
display(df.head())
df.columns.tolist()
# Out:
# Loading Grand Slam matches…
# (1840, 289)
#    match_id       tournament             location       date  year  \
# 0         0  Australian Open  Melbourne,Australia 2018-01-15  2018
# 1         1  Australian Open  Melbourne,Australia 2018-01-15  2018
# 2         2  Australian Open  Melbourne,Australia 2018-01-15  2018
# 3         3  Australian Open  Melbourne,Australia 2018-01-15  2018
# 4         4  Australian Open  Melbourne,Australia 2018-01-15  2018
#
#    tournament_code        stage match_duration  winners_set1  winners_set2  \
# 0            580.0  Round of 64            NaN           6.0           6.0
# 1            580.0  Round of 64            NaN           6.0           6.0
# 2            580.0  Round of 64            NaN           6.0           6.0
# 3            580.0  Round of 64            NaN           7.0           6.0
# 4            580.0  Round of 64            NaN           6.0           6.0
#
# ...

# %%
# pair-level variables you want
desc_vars_win = [
    "same_coach_winners",
    "same_country_winners",
    "winners_same_language",
    "winners_linguistic_proximity",
    "same_hand_winners",
    "same_backhand_winners",
    "height_diff_winners",
    "weight_diff_winners",
    "experience_diff_winners"
]

desc_vars_lose = [
    "same_coach_losers",
    "same_country_losers",
    "losers_same_language",
    "losers_linguistic_proximity",
    "same_hand_losers",
    "same_backhand_losers",
    "height_diff_losers",
    "weight_diff_losers",
    "experience_diff_losers"
]

# common names you want in the final pair-level dataset
common_vars = [
    "same_coach",
    "same_country",
    "same_language",
    "linguistic_proximity",
    "same_hand",
    "same_backhand",
    "height_diff",
    "weight_diff",
    "experience_diff"
]

# %%
def make_pair(name1, surname1, name2, surname2):
    p1 = f"{name1} {surname1}".strip()
    p2 = f"{name2} {surname2}".strip()
    return " / ".join(sorted([p1, p2]))

df["winner_pair"] = df.apply(
    lambda row: make_pair(
        row["winners_p1_name"], row["winners_p1_surname"],
        row["winners_p2_name"], row["winners_p2_surname"]
    ),
    axis=1
)

df["loser_pair"] = df.apply(
    lambda row: make_pair(
        row["losers_p1_name"], row["losers_p1_surname"],
        row["losers_p2_name"], row["losers_p2_surname"]
    ),
    axis=1
)
# Out:
# C:\Users\ALESSANDRO\AppData\Local\Temp\ipykernel_19000\607057472.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["winner_pair"] = df.apply(
# C:\Users\ALESSANDRO\AppData\Local\Temp\ipykernel_19000\607057472.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["loser_pair"] = df.apply(

# %%
def build_pair_dataset(df, win_pair_col, lose_pair_col, win_vars, lose_vars, common_vars):
    winners_long = df[[win_pair_col] + win_vars].copy()
    winners_long["wins"] = 1
    winners_long["losses"] = 0
    winners_long = winners_long.rename(columns={win_pair_col: "pair"})
    winners_long.columns = ["pair"] + common_vars + ["wins", "losses"]

    losers_long = df[[lose_pair_col] + lose_vars].copy()
    losers_long["wins"] = 0
    losers_long["losses"] = 1
    losers_long = losers_long.rename(columns={lose_pair_col: "pair"})
    losers_long.columns = ["pair"] + common_vars + ["wins", "losses"]

    pair_match_level = pd.concat([winners_long, losers_long], ignore_index=True)

    pair_dataset = (
        pair_match_level
        .groupby("pair", as_index=False)
        .agg(
            {"wins": "sum", "losses": "sum", **{v: "mean" for v in common_vars}}
        )
    )

    pair_dataset["matches"] = pair_dataset["wins"] + pair_dataset["losses"]
    pair_dataset["win_rate"] = pair_dataset["wins"] / pair_dataset["matches"]

    return pair_dataset

# %%
pair_dataset = build_pair_dataset(
    df,
    win_pair_col="winner_pair",
    lose_pair_col="loser_pair",
    win_vars=desc_vars_win,
    lose_vars=desc_vars_lose,
    common_vars=common_vars
)

# %%
# =============================
# Save
# =============================
print(f"Saving to {OUTPUT_FILE} …")
with pd.ExcelWriter(OUTPUT_FILE, engine="xlsxwriter") as xlw:
    pair_dataset.to_excel(xlw, index=False, sheet_name="players_list")

print("Done.")
# Out:
# Saving to C:/Users/ALESSANDRO/Documents/GitHub/tennis-homophily/data/atp/pairs_df.xlsx …
# Done.

# %%
topN = pair_dataset.nlargest(30, "wins")

avg_numeric = topN.select_dtypes(include="number").mean()

avg_numeric
# Out:
# wins                    17.600000
# losses                   6.033333
# same_coach               0.066667
# same_country             0.448276
# same_language            0.655172
# linguistic_proximity     0.655172
# same_hand                0.700000
# same_backhand            0.633333
# height_diff              5.206897
# weight_diff              5.413793
# experience_diff          4.629630
# matches                 23.633333
# win_rate                 0.747868
# dtype: float64
